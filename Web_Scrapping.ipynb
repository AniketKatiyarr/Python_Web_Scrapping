# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
Player_url = "https://search.espncricinfo.com/ci/content/site/search.html?search=" + "ViratKohli"

# %%
Player_url
# Out:
# 'https://search.espncricinfo.com/ci/content/site/search.html?search=ViratKohli'

# %%
urlclient = urlopen(Player_url)

# %%
url_html = urlclient.read()

# %%
player_html = bs(url_html, "html.parser")

# %%
player_html
# Out:
# <!DOCTYPE html>
#
# <!-- hostname: web03, edition-view: , country: unknown, cluster: www, created: 2023-10-28 05:58:58 -->
# <!--[if IE 8]><html class="lt-ie9" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]-->
# <!--[if IE 9]><html class="ie9" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]-->
# <!--[if gt IE 9]><!--> <html lang="en"> <!--<![endif]-->
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <meta content="ZxdgH3XglRg0Bsy-Ho2RnO3EE4nRs53FloLS6fkt_nc" name="google-site-verification">
# <title>Search "ViratKohli" | ESPNcricinfo.com</title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# ...

# %%
big_box = player_html.find_all("ul",{"class":"story-list three-item-stack"})

# %%
big_box
# Out:
# [<ul class="story-list three-item-stack">
#  <li>
#  <div class="thumbnail">
#  <div class="img-wrap">
#  <picture>
#  <a href="/ci/content/story/1341333.html"><img alt="" src="/db/PICTURES/CMS/348000/348077.8.jpg" title=""/></a>
#  </picture>
#  </div>
#  </div>
#  <div class="content-stack">
#  <p>What They Said About</p>
#  <h3 class="link-cta"><a href="/ci/content/story/1341333.html">'Virat Kohli, what are you?'</a></h3>
#  <p><span class="bold date">Oct 23, 2022</span> <span class="blurb">- It was a contest for the ages, and ended in dramatic circumstances - with Virat Kohli at the centre of it. Here's how the cricket community reacted</span></p>
#  </div>
#  </li>
#  <li>
#  <div class="thumbnail">
#  <div class="img-wrap">
#  <picture>
#  <a href="/ci/content/story/1297111.html"><img alt="" src="/db/PICTURES/CMS/326200/326267.8.jpg" title=""/></a>
#  </picture>
#  </div>
#  </div>
#  <div class="content-stack">
#  <p>What They Said About</p>
# ...

# %%
len(big_box)
# Out:
# 1

# %%
player_link = "https://search.espncricinfo.com" + big_box[0].li.div.div.picture.a["href"]

# %%
for i in big_box:
    print("https://search.espncricinfo.com" + i.li.div.div.picture.a["href"])
# Out:
# https://search.espncricinfo.com/ci/content/story/1341333.html

# %%
player_link
# Out:
# 'https://search.espncricinfo.com/ci/content/story/1341333.html'

# %%
player_req = requests.get(player_link)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ...
